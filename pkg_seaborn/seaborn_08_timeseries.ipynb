# %%
# recorded by hao (2018/03/10)
# rock3.hao@gmail.com
# qinlab.BNU

# training of seaborn 08

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
np.random.seed(3)

# %%
x = np.linspace(0, 15, 31)
data = np.sin(x) + np.random.rand(10, 31) + np.random.randn(10, 1)
# print(data)
ax = sns.tsplot(data=data)
# Out:
# /Applications/Anaconda/anaconda3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
gammas = sns.load_dataset("gammas")
gammas.head(6)
# Out:
#    timepoint  ROI  subject  BOLD signal
# 0        0.0  IPS        0     0.513433
# 1        0.0  IPS        1    -0.414368
# 2        0.0  IPS        2     0.214695
# 3        0.0  IPS        3     0.814809
# 4        0.0  IPS        4    -0.894992
# 5        0.0  IPS        5    -0.073709

# %%
ax = sns.tsplot(time="timepoint", value="BOLD signal",
                 unit="subject", condition="ROI",
                 data=gammas)
# Out:
# /Applications/Anaconda/anaconda3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
ax = sns.tsplot(data=data, err_style="ci_bars", color="g")
#{ci_band, ci_bars, boot_traces, boot_kde, unit_traces, unit_points}
# Out:
# /Applications/Anaconda/anaconda3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
ax = sns.tsplot(data=data, err_style="ci_bars", interpolate=False)
# Out:
# /Applications/Anaconda/anaconda3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
ax = sns.tsplot(data=data, estimator=np.median)
# Out:
# /Applications/Anaconda/anaconda3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
ax = sns.tsplot(data=data, err_style="boot_traces", n_boot=100)
# Out:
# /Applications/Anaconda/anaconda3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
ax = sns.tsplot(data=data, err_style="unit_traces")
# Out:
# /Applications/Anaconda/anaconda3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
